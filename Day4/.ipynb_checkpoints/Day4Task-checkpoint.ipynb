# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('insurance.csv')
df = df[['age', 'bmi', 'children', 'charges']]
df
# Out:
#       age     bmi  children      charges
# 0      19  27.900         0  16884.92400
# 1      18  33.770         1   1725.55230
# 2      28  33.000         3   4449.46200
# 3      33  22.705         0  21984.47061
# 4      32  28.880         0   3866.85520
# ...   ...     ...       ...          ...
# 1333   50  30.970         3  10600.54830
# 1334   18  31.920         0   2205.98080
# 1335   18  36.850         0   1629.83350
# 1336   21  25.800         0   2007.94500
# 1337   61  29.070         0  29141.36030
#
# [1338 rows x 4 columns]

# %%
scaler = StandardScaler()
z = scaler.fit_transform(df[['age', 'bmi', 'children', 'charges']])
z
# Out:
# array([[-1.43876426, -0.45332   , -0.90861367,  0.2985838 ],
#        [-1.50996545,  0.5096211 , -0.07876719, -0.95368917],
#        [-0.79795355,  0.38330685,  1.58092576, -0.72867467],
#        ...,
#        [-1.50996545,  1.0148781 , -0.90861367, -0.96159623],
#        [-1.29636188, -0.79781341, -0.90861367, -0.93036151],
#        [ 1.55168573, -0.26138796, -0.90861367,  1.31105347]])

# %%
df['z age'] = z[:,0]
df['z bmi'] = z[:,1]
df['z children'] = z[:,2]
df['z charges'] = z[:,3]
df
# Out:
#       age     bmi  children      charges     z age     z bmi  z children  \
# 0      19  27.900         0  16884.92400 -1.438764 -0.453320   -0.908614
# 1      18  33.770         1   1725.55230 -1.509965  0.509621   -0.078767
# 2      28  33.000         3   4449.46200 -0.797954  0.383307    1.580926
# 3      33  22.705         0  21984.47061 -0.441948 -1.305531   -0.908614
# 4      32  28.880         0   3866.85520 -0.513149 -0.292556   -0.908614
# ...   ...     ...       ...          ...       ...       ...         ...
# 1333   50  30.970         3  10600.54830  0.768473  0.050297    1.580926
# 1334   18  31.920         0   2205.98080 -1.509965  0.206139   -0.908614
# 1335   18  36.850         0   1629.83350 -1.509965  1.014878   -0.908614
# 1336   21  25.800         0   2007.94500 -1.296362 -0.797813   -0.908614
# 1337   61  29.070         0  29141.36030  1.551686 -0.261388   -0.908614
#
#       z charges
# 0      0.298584
# 1     -0.953689
# 2     -0.728675
# 3      0.719843
# ...

# %%
plt.subplot(231)
plt.scatter(df['age'], df['charges'])
plt.subplot(232)
plt.scatter(df['bmi'], df['charges'])
plt.subplot(233)
plt.scatter(df['children'], df['charges'])

plt.subplot(234)
plt.scatter(df['z age'], df['z charges'])
plt.subplot(235)
plt.scatter(df['z bmi'], df['z charges'])
plt.subplot(236)
plt.scatter(df['z children'], df['z charges'])

plt.show()

# %%
model = LinearRegression()
model.fit(df[['z age', 'z bmi', 'z children']], df['z charges'])
m = model.coef_
c = model.intercept_
print(m)
print(c)
# Out:
# [0.27844011 0.16722581 0.05403954]
# 1.0479768376707869e-17

# %%
df['z charges ŷ'] = model.predict(df[['z age', 'z bmi', 'z children']])
df
# Out:
#       age     bmi  children      charges     z age     z bmi  z children  \
# 0      19  27.900         0  16884.92400 -1.438764 -0.453320   -0.908614
# 1      18  33.770         1   1725.55230 -1.509965  0.509621   -0.078767
# 2      28  33.000         3   4449.46200 -0.797954  0.383307    1.580926
# 3      33  22.705         0  21984.47061 -0.441948 -1.305531   -0.908614
# 4      32  28.880         0   3866.85520 -0.513149 -0.292556   -0.908614
# ...   ...     ...       ...          ...       ...       ...         ...
# 1333   50  30.970         3  10600.54830  0.768473  0.050297    1.580926
# 1334   18  31.920         0   2205.98080 -1.509965  0.206139   -0.908614
# 1335   18  36.850         0   1629.83350 -1.509965  1.014878   -0.908614
# 1336   21  25.800         0   2007.94500 -1.296362 -0.797813   -0.908614
# 1337   61  29.070         0  29141.36030  1.551686 -0.261388   -0.908614
#
#       z charges  z charges ŷ
# 0      0.298584    -0.525518
# 1     -0.953689    -0.339470
# ...

# %%
inv = scaler.inverse_transform(df[['z age', 'z bmi', 'z children', 'z charges ŷ']])
df['charges ŷ'] = inv[:,3]
df
# Out:
#       age     bmi  children      charges     z age     z bmi  z children  \
# 0      19  27.900         0  16884.92400 -1.438764 -0.453320   -0.908614
# 1      18  33.770         1   1725.55230 -1.509965  0.509621   -0.078767
# 2      28  33.000         3   4449.46200 -0.797954  0.383307    1.580926
# 3      33  22.705         0  21984.47061 -0.441948 -1.305531   -0.908614
# 4      32  28.880         0   3866.85520 -0.513149 -0.292556   -0.908614
# ...   ...     ...       ...          ...       ...       ...         ...
# 1333   50  30.970         3  10600.54830  0.768473  0.050297    1.580926
# 1334   18  31.920         0   2205.98080 -1.509965  0.206139   -0.908614
# 1335   18  36.850         0   1629.83350 -1.509965  1.014878   -0.908614
# 1336   21  25.800         0   2007.94500 -1.296362 -0.797813   -0.908614
# 1337   61  29.070         0  29141.36030  1.551686 -0.261388   -0.908614
#
#       z charges  z charges ŷ     charges ŷ
# 0      0.298584    -0.525518   6908.777533
# ...
